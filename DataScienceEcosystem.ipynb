# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# Aqui estao alguns exemplos para linguagens e ferramentas mais comuns entre os Cientistas de dados

# %% [markdown]
# ### Objetivos
#
# * Listar linguagens populares
# * Bibliotecas mais utilizadas
# * Ferramentas
# * expressoes arimeticas
# * aplicacao minutos -> horas
# * Autor

# %% [markdown]
# Algumas das linguagens populares que os Cientistas de Dados usam são:
# 1. Python
# 2. R
# 3. SQL
# 4. JAVA
# 5. C++

# %% [markdown]
# As bibliotecas comumente utilizadas pelos cientistas
#
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. scikit-learn
# 5. tensorflow
# 6. keras

# %% [markdown]
# | Ferramentas de Ciência de Dados |
# |----------------------------------|
# | ANACONDA                         |
# | RSTUDIO|
# | VSCODE                          |
# | SPIDER                        |
# | IBM WATSON STUDIO                           |
# | GOOGLE COLAB                   |

# %% [markdown]
# ### Abaixo estão alguns exemplos de avaliação de expressões aritméticas em Python.

# %%
(3*4)+5
# Out:
# 17

# %%
#Convertendo horas em minutos
200/60
#Isso converterá 200 minutos em horas dividindo por 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor
# Gustavo Kenji Mushino Viana
